# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
a = np.load('./data/Nischay.npy')

# %%
print a.shape
# Out:
# (22, 30000)

# %%
b = a[2].reshape(100,100,-1)
print b.shape
# Out:
# (100, 100, 3)

# %%
plt.imshow(cv2.cvtColor(b,cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Now we have examples in our data folder. We just take in input image and matches it with examples using KNN
